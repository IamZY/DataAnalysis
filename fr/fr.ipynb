# %%
import pandas as pd
df = pd.read_csv("test.csv")
df.head()
# Out:
#   等级       【编码】  生产类企业综合效益评价_本期_综合评价通用指标.本期值  盈利状况_本期_综合评价通用指标.本期值  \
# 0  A  134972999                        0.289                   NaN
# 1  A  134977546                        0.280                   NaN
# 2  A  135665907                        0.325                   NaN
# 3  A  249770860                        0.307                   NaN
# 4  A  567218406                        0.297                   NaN
#
#    收益及增长情况_本期_综合评价通用指标.本期值  亩均生产总值（生产总值／占地亩数）_本期_综合评价通用指标.本期值  \
# 0                      NaN                             24.881
# 1                      NaN                              2.750
# 2                      NaN                              8.979
# 3                      NaN                            146.660
# 4                      NaN                              4.448
#
#    净资产收益率（税后利润／净资产）A_本期_综合评价通用指标.本期值  \
# 0                            106.378
# 1                             12.193
# 2                             60.664
# ...

# %%
df = pd.read_csv("train.csv")
df.tail(5)
# Out:
#           【编码】  生产类企业综合效益评价_本期_综合评价通用指标.本期值  盈利状况_本期_综合评价通用指标.本期值  \
# 228  793731283                        0.239                   NaN
# 229  797127841                        0.256                   NaN
# 230  55209157X                        0.244                   NaN
# 231  66739444X                        0.244                   NaN
# 232  73316124X                        0.231                   NaN
#
#      收益及增长情况_本期_综合评价通用指标.本期值  亩均生产总值（生产总值／占地亩数）_本期_综合评价通用指标.本期值  \
# 228                      NaN                                NaN
# 229                      NaN                              1.506
# 230                      NaN                              2.863
# 231                      NaN                              4.830
# 232                      NaN                                NaN
#
#      净资产收益率（税后利润／净资产）A_本期_综合评价通用指标.本期值  \
# 228                             -2.252
# 229                            -58.131
# 230                             -2.947
# ...
