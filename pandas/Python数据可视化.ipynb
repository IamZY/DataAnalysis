# %%
from matplotlib import pyplot as plt

plt.plot([1,2,2,1])
plt.show()

# %%
# %matplotlib inline
plt.plot([1,2,2,1])

# %%
fig1 = plt.figure(figsize = (10,5))
plt.plot([1,2,2,1])

# %%
plt.plot([1,2,2,1])

# %%
fig1

# %%
plt.plot([1,2,2,1])

# %%
plt.plot([4,2,3,1],[1,2,2,1])

# %%
plt.plot([1,2,2,1])
plt.plot([4,2,3,1],[1,2,2,1])

# %%
plt.plot([4,2,3,1],[1,2,2,1],'ro--')

# %%
plt.plot([4,2,3,1],[1,2,2,1],'ro--',linewidth=3.5)

# %%
plt.plot([4,2,3,1],[1,2,2,1],'ro--',linewidth=3.5)
plt.annotate("This is a point",xy=(3,2))
plt.xlabel("$X\ value$")
# Out:
# Text(0.5, 0, '$X\\ value$')

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.1'

# %%
import seaborn
seaborn.__version__
# Out:
# '0.9.0'

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.rcParams["font.family"] = "SimHei"
plt.plot([-1,2,2,1])
plt.xlabel("中文字体")
# Out:
# Text(0.5, 0, '中文字体')
# d:\python37\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\python37\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.rcParams["font.family"] = "STXIHEI"
plt.plot([-1,2,2,1])
plt.xlabel("中文字体")
# Out:
# Text(0.5, 0, '中文字体')

# %%
import pandas as pd
ccss = pd.read_excel("ccss_sample.xlsx")
ccss.head()
# Out:
#      time  id  s0 s2  s3     s4             s5  s7          s9 c0_1  ...  \
# 0  200704   1  北京  男  20     本科     公司普通职员（白领）  未婚  2000-2999元    0  ...
# 1  200704   2  北京  男  24  高中/中专     公司普通职员（白领）  未婚  6000-7999元    0  ...
# 2  200704   3  上海  男  20  高中/中专  无业/待业/失业/家庭主妇  未婚  1000-1499元    0  ...
# 3  200704   4  北京  女  65     大专       企/事业管理人员  已婚  1000-1499元    0  ...
# 4  200704   5  上海  女  40  高中/中专     公司普通职员（白领）  已婚      99拒绝回答    0  ...
#
#       Qs9  Qa3  Qa4  Qa8  Qa9 Qa10  Qa16      index1     index1a     index1b
# 0  2500.0  100  200  200  200  100   100  109.349371   88.035919  121.071238
# 1  7000.0  100  100  100  150  200   100   93.728032   88.035919   96.856991
# 2  1250.0  100  150  150  100  100   100   93.728032   88.035919   96.856991
# 3  1250.0  150  150  100  100  100   200  109.349371  154.062858   84.749867
# 4     NaN  100  100  100  100  150   100   85.917363   88.035919   84.749867
#
# [5 rows x 32 columns]

# %%
pd.value_counts(ccss.s5)
# Out:
# 公司普通职员（白领）       349
# 企/事业管理人员         177
# 退休               125
# 个体经营者/私营业主       123
# 无业/待业/失业/家庭主妇     87
# 工人/体力工作者（蓝领）      81
# 其他职业              51
# 专业人士（如医生、律师等）     51
# 教师                43
# 国家公务员             33
# 学生                27
# Name: s5, dtype: int64

# %%
pd.value_counts(ccss.s5).plot.bar()

# %%
plt.bar(pd.value_counts(ccss.s5).index,pd.value_counts(ccss.s5))
# Out:
# <BarContainer object of 11 artists>

# %%
sns.barplot(
    x = pd.value_counts(ccss.s5).index,
    y = pd.value_counts(ccss.s5)
)

# %%
pd.DataFrame(pd.value_counts(ccss.s5)).T
# Out:
#     公司普通职员（白领）  企/事业管理人员   退休  个体经营者/私营业主  无业/待业/失业/家庭主妇  工人/体力工作者（蓝领）  其他职业  \
# s5         349       177  125         123             87            81    51
#
#     专业人士（如医生、律师等）  教师  国家公务员  学生
# s5             51  43     33  27

# %%
sns.barplot(data = pd.DataFrame(pd.value_counts(ccss.s5)).T)

# %%
sns.barplot(data = pd.DataFrame(pd.value_counts(ccss.s5)).T,color="#ff0000")

# %%
sns.barplot(
    x = pd.value_counts(ccss.s4).index,
    y = pd.value_counts(ccss.s4)
)

# %%
sns.barplot(
    x = pd.value_counts(ccss.s4).index,
    y = pd.value_counts(ccss.s4),
    order = ["本科","大专"]
)

# %%
sns.countplot(ccss.s4)

# %%
ccss.s5.value_counts().plot.pie()

# %%
plt.pie(ccss.s5.value_counts(),labels = ccss.s5.value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1db3437ba20>,
# ...
#  [Text(0.6345623390735707, 0.8985157972064146, '公司普通职员（白领）'),
#   Text(-0.8085979170513424, 0.7457676639143257, '企/事业管理人员'),
#   Text(-1.096288627682113, -0.09028424455501469, '退休'),
#   Text(-0.7962333868005624, -0.7589548034923463, '个体经营者/私营业主'),
#   Text(-0.25525151120719014, -1.0699750772921983, '无业/待业/失业/家庭主妇'),
#   Text(0.24645129617091988, -1.072036267397551, '工人/体力工作者（蓝领）'),
#   Text(0.609717501022867, -0.9155569719828638, '其他职业'),
#   Text(0.838546444984093, -0.7119268639435792, '专业人士（如医生、律师等）'),
#   Text(0.992183544810845, -0.4749440108124176, '教师'),
#   Text(1.0689173641223912, -0.2596452747069347, '国家公务员'),
#   Text(1.0969934783194408, -0.08127304918984332, '学生')])

# %%
plt.pie([0.1,0.2,0.1,0.3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1db353b1e48>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-0.6465638066837905, 0.8899186726249574, ''),
#   Text(-1.0461621424642782, -0.3399187721714579, '')])

# %%
plt.figure(figsize=(16,8))
plt.pie(ccss.s5.value_counts(normalize = True)/2,labels = ccss.s5.value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1db353ffd68>,
# ...
#  [Text(0.9767339896258674, 0.505955248524547, '公司普通职员（白领）'),
#   Text(0.4003387885550959, 1.0245627625373852, '企/事业管理人员'),
#   Text(-0.04518024761815632, 1.099071765275208, '退休'),
#   Text(-0.4087439751968103, 1.0212386414253574, '个体经营者/私营业主'),
#   Text(-0.6816242871524205, 0.86335874997822, '无业/待业/失业/家庭主妇'),
#   Text(-0.8605511099836001, 0.6851655180363312, '工人/体力工作者（蓝领）'),
#   Text(-0.9697136822601695, 0.5192835202829214, '其他职业'),
#   Text(-1.0325698740236668, 0.37920898625790617, '专业人士（如医生、律师等）'),
#   Text(-1.072707299148265, 0.24351396336562559, '教师'),
#   Text(-1.092201698527939, 0.13074956876672633, '国家公务员'),
#   Text(-1.0992481126095657, 0.040664320039902196, '学生')])

# %%
plt.pie([1])
# Out:
# ([<matplotlib.patches.Wedge at 0x1db35468cf8>],
#  [Text(-1.1, 1.3471114790620887e-16, '')])

# %%
plt.pie([1],colors=["#ffffff"],radius = 0.7)
# Out:
# ([<matplotlib.patches.Wedge at 0x1db354af4e0>],
#  [Text(-0.77, 9.42978035343462e-17, '')])

# %%
plt.figure(figsize=(16,8))
plt.pie(ccss.s5.value_counts(),labels = ccss.s5.value_counts().index)
plt.pie([1],colors = ["#ffffff"],radius = 0.7)
# Out:
# ([<matplotlib.patches.Wedge at 0x15fd7b39128>],
#  [Text(-0.77, 9.42978035343462e-17, '')])

# %%
sns.stripplot(y = ccss.s3[:200],jitter = False)

# %%
sns.stripplot(y = ccss.s3[:200],jitter = True)

# %%
sns.swarmplot(y = ccss.s3[:200])

# %%
ccss.s3.plot.hist()

# %%
plt.hist(ccss.s3)
# Out:
# (array([126., 242., 207., 113.,  84.,  94.,  84.,  59.,  84.,  54.]),
#  array([18. , 22.7, 27.4, 32.1, 36.8, 41.5, 46.2, 50.9, 55.6, 60.3, 65. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(ccss.s3,hist = False,kde = False,rug = True)

# %%
sns.distplot(ccss.s3,kde = False)

# %%
sns.distplot(ccss.s3)

# %%
# 和正态分布曲线相比较
from scipy.stats import norm
sns.distplot(ccss.s3,fit=norm)

# %%
sns.distplot(
    ccss.s3 , 
    rug = True,
    rug_kws = {"colors":"g"},
    kde_kws = {"color":"k","lw":3,"label":"kde"},
    hist_kws={"linewidth":3,"color":"y","label":"Hist"})

# %%
sns.kdeplot(ccss.s3,bw=.5,label = "bw : 0.5")
sns.kdeplot(ccss.s3,bw=1,label = "bw : 1")
sns.kdeplot(ccss.s3,bw=2,label = "bw : 2")

# %%
ccss.s3.plot.box()

# %%
plt.boxplot(ccss.s3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15fd93c0d68>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15fd93d7550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15fd93caa58>],
#  'medians': [<matplotlib.lines.Line2D at 0x15fd93d7c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15fd93d7f60>],
#  'means': []}

# %%
sns.boxplot(y = ccss.s3)

# %%
sns.boxplot(y = ccss.index1,saturation = 0.3,width = 0.5,linewidth = 3,fliersize = 10)

# %%
sns.boxenplot(x = ccss.s2,y = ccss.index1)

# %%
sns.boxenplot(x = ccss.time,y = ccss.index1,outlier_prop = 0.1)   # 显示更多的离群值

# %%
sns.boxenplot(x = ccss.time,y = ccss.index1,scale = "area",outlier_prop = 0.1)

# %%
sns.violinplot(y = ccss.s3)

# %%
sns.violinplot(y = ccss.s3,inner = "quartile")

# %%
sns.violinplot(y = ccss.s3,inner = None)

# %%
sns.violinplot(y = ccss.s3,inner = None)
sns.swarmplot(y = ccss.s3,size = 2,color='k')

# %%
sns.barplot(x = ccss.s4,y = ccss.s3)

# %%
sns.barplot(x = ccss.s4,y = ccss.s3,color = 'c',errcolor = 'b',errwidth = '2',capsize = .3)

# %%
sns.barplot(x = ccss.s4,y = ccss.s3,ci = None)
plt.xlabel("教育程度")
plt.ylabel("年龄均值")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-3e20f6e1a614> in <module>
#       1 sns.barplot(x = ccss.s4,y = ccss.s3,ci = None)
# ----> 2 plt.xlabel("教育程度")
#       3 plt.ylabel("年龄均值")
#
# TypeError: 'str' object is not callable

# %%
import numpy as np
sns.barplot(x = ccss.s4,y = ccss.s3,estimator = np.median)

# %%
sns.barplot(x = ccss.s4,y = ccss.s3,estimator = np.std)

# %%
sns.barplot(x = ccss.s4,y = ccss.s3,hue = ccss.s2)

# %%
sns.barplot(x = ccss.Qs9,y = ccss.s3,hue = ccss.Ts9)

# %%
sns.barplot(x = ccss.Qs9,y = ccss.s3,hue = ccss.Ts9,dodge = False)

# %%
# 
tmpdf = pd.crosstab(index = ccss.s0,columns = ccss.s4)
tmpdf
# Out:
# s4  初中/技校或以下   大专   本科  硕士或以上  高中/中专
# s0
# 上海        47   87  108     23    122
# 北京        59  116  101     19     83
# 广州        48  128   83     15    108

# %%
tmpdf.loc[['上海']]
# Out:
# s4  初中/技校或以下  大专   本科  硕士或以上  高中/中专
# s0
# 上海        47  87  108     23    122

# %%
tmpdf.loc['上海']  # 序列格式
# Out:
# s4
# 初中/技校或以下     47
# 大专           87
# 本科          108
# 硕士或以上        23
# 高中/中专       122
# Name: 上海, dtype: int64

# %%
sns.barplot(data = tmpdf.loc[["上海"]],color = "b",label = "上海")
sns.barplot(data = tmpdf.loc[["北京"]],bottom = tmpdf.loc["上海"],color = "c",label = "北京")
sns.barplot(data = tmpdf.loc[["广州"]],bottom = tmpdf.loc["北京"] + tmpdf.loc["上海"],color = "y",label = "广州")
plt.legend()

# %%
sumdata = ccss.groupby("time").index1.mean()

# %%
sumdata
# Out:
# time
# 200704     98.336327
# 200712     94.139120
# 200812     90.439330
# 200912    101.996231
# Name: index1, dtype: float64

# %%
sumdata.plot()

# %%
plt.plot(sumdata)

# %%
sumdata.index.astype("str")
# Out:
# Index(['200704', '200712', '200812', '200912'], dtype='object', name='time')

# %%
sns.lineplot(ccss.time,ccss.index1)

# %%
sns.lineplot(ccss.time.astype("str"),ccss.index1,err_style = "bars")

# %%
sns.lineplot(ccss.s3,ccss.index1,ci = None)

# %%
sns.lineplot(ccss.s3,ccss.index1,hue = ccss.s2,ci = None)

# %%
sns.lineplot("s4","index1",data = ccss,style = "s0",size = "s0",ci = None)

# %%
sns.pointplot(x = ccss.time,y = ccss.index1,capsize = .1)

# %%
ccss.groupby('a3').index1.mean().plot.area()

# %%
tmpdf = pd.crosstab(index = ccss.s4,columns = ccss.O1)
tmpdf
# Out:
# O1          有   没有
# s4
# 初中/技校或以下   19  135
# 大专        106  224
# 本科        107  185
# 硕士或以上      24   33
# 高中/中专      56  255

# %%
tmpdf.plot.area()

# %%
tmpdf.plot.area(stacked = False)

# %%
ccss.plot.scatter("s3","index1")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
plt.scatter(ccss.s3,ccss.index1,s = ccss.index1,c = ccss.index1)

# %%
sns.scatterplot(ccss.s3,ccss.index1)

# %%
sns.scatterplot(ccss.s3,ccss.index1,hue = ccss.s2)

# %%
sns.scatterplot(ccss.s3,ccss.index1,hue = ccss.s2,size = ccss.Qs9)

# %%
sns.lmplot(x = "s3",y = "index1",data = ccss)

# %%
sns.lmplot(x = "s3",y = "index1",data = ccss,x_bins = 15)

# %%
sns.lmplot(x = "s3",y = "index1",data = ccss,x_estimator = np.mean)

# %%
anscombe = sns.load_dataset("anscombe")
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(x = "x",y = "y",data = anscombe.query("dataset == 'I' "),ci = None)

# %%
sns.lmplot(x = "x",y = "y",data = anscombe.query("dataset == 'I' "),ci = None,robust = True)

# %%
sns.residplot(x = "x",y = "y",data = anscombe.query("dataset == 'I'"))

# %%
sns.residplot(x = "x",y = "y",data = anscombe.query("dataset == 'II'"))

# %%
sns.residplot(x = "x",y = "y",data = anscombe.query("dataset == 'II'"),order= 2)

# %%
sns.lmplot(x = "s3",y = "index1",hue = "s2",data = ccss)

# %%
sns.lmplot(x = "s3",y = "index1",hue = "s2",data = ccss,lowess = True)

# %%
sns.lmplot(x = "s3", y = "index1",hue = "s2",col = "time",data = ccss,lowess = True,col_wrap = 2)

# %%
sns.lmplot(x = "s3", y = "index1",hue = "s2",col = "time", row = "s0",data = ccss)

# %%
sns.lmplot(x = "s3", y = "index1",hue = "s2",col = "time", row = "s0",data = ccss,truncate = True)

# %%
sns.lmplot(x = "s3", y = "index1",hue = "s2",col = "time", row = "s0",data = ccss,sharex = False)

# %%
sns.jointplot(x = "s3",y = "index1",data = ccss,kind = "reg")

# %%
sns.jointplot(x = "s3",y = "index1",data = ccss,kind = "hex")

# %%
plt.hexbin(x = ccss.s3,y = ccss.index1,gridsize = (40,40))

# %%
sns.jointplot(x = "s3",y = "index1",data = ccss,kind = "kde")

# %%
sns.kdeplot(ccss.s3,ccss.index1)

# %%
sns.kdeplot(ccss.s3,ccss.index1,shade = True,n_levels = 10)

# %%
sns.kdeplot(ccss.s3,ccss.index1,shade = True,cbar = True,n_levels = 10)

# %%
sns.pairplot(data = ccss,vars = ["index1","index1a","index1b"])

# %%
sns.pairplot(data = ccss,x_vars = "s3",y_vars = ["index1a","index1b"],kind = "reg",hue = "s2",height = 4,aspect = 1.5)

# %%
sns.PairGrid(data = ccss,vars = ["index1","index1a","index1b"]).map(sns.scatterplot)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(ccss.s3,ccss.index1a,ccss.index1b)

# %%
plt.plot([1,2,2,1],label = "A line")

# %%
plt.plot([1,2,2,1],label = "A line")
plt.legend()

# %%
plt.plot([1,2,2,1])
plt.legend(["Line Label"])

# %%
plt.plot([1,2,2,1])
plt.legend(["Line Label"],loc = (0.5,0.5))

# %%
l1, = plt.plot([1,2,2,1],label  = "sdsd")
l2, = plt.plot([1,2.5,2.5,1])
plt.legend(handles = [l1,l2],labels = ["line label","line2"],loc = "best")

# %%
sns.lineplot("s4","index1",data = ccss,size = "Qs9",ci = None,legend = "full")

# %%
ax1 = sns.kdeplot(ccss.s3)

# %%
ax1 = sns.kdeplot(ccss.s3)
sns.distplot(ccss.s3,kde = False,norm_hist = True,ax = ax1)

# %%
ax1 = sns.kdeplot(ccss.s3)
ax1.hist(ccss.s3,density = True)
# Out:
# (array([0.02337272, 0.04489046, 0.03839804, 0.02096125, 0.01558181,
#         0.01743679, 0.01558181, 0.01094437, 0.01558181, 0.01001688]),
#  array([18. , 22.7, 27.4, 32.1, 36.8, 41.5, 46.2, 50.9, 55.6, 60.3, 65. ]),
#  <a list of 10 Patch objects>)

# %%
ccss.plot.kde(y = "index1",secondary_y = True)

# %%
ccss.loc[:,["index1","s3"]].plot.kde(secondary_y= "s3")

# %%
plt.gca().twinx()

# %%
ccss.index1.plot.kde(label = "index1")
plt.gca().set_ylabel("$index1$")

ax2 = plt.gca().twinx()
sns.kdeplot(ccss.s3,legend = None,ax = ax2,color='g')
ax2.set_ylabel("$s3$")
# Out:
# Text(0, 0.5, '$s3$')

# %%
sns.catplot(x = "time",y = "index1",col = "s0",data = ccss,kind = "box")

# %%
sns.catplot(x = "time",y = "index1",col = "s0",data = ccss,kind = "boxen")

# %%
sns.catplot(x = "time",y = "index1",col = "s0",data = ccss,kind = "violin")

# %%
sns.catplot(x = "time",y = "index1",col = "s0",hue = "s2",data = ccss,kind = "bar")

# %%
sns.catplot(x = "time",y = "index1",col = "s0",hue = "s2",data = ccss,col_wrap = 2,kind = "bar",legend_out = False)

# %%
sns.pointplot(ccss.time,ccss.index1,capsize = .1)
fig = plt.gcf()
fig.add_axes([0.15,0.2,0.25,0.2])
sns.distplot(ccss.index1,kde = False)

# %%
plt.subplot(221)
plt.subplot(222)
plt.subplot(212)
plt.plot([1,2,2,1])

# %%
plt.subplot(221)
ax1 = plt.subplot(222)
plt.subplot(212)
plt.sca(ax1)
plt.plot([1,2,2,1])

# %%
f,(ax1,ax2) = plt.subplots(1,2)
sns.boxplot(y = ccss.index1,ax = ax1)
ax1.set_title("总信心指数")
sns.boxplot(y = ccss.s3,ax = ax2)
ax2.set_title("年龄")
# Out:
# Text(0.5, 1.0, '年龄')

# %%
sns.set()
plt.plot([1,2,2,1])

# %%
sns.set_style("white")
plt.plot([1,2,2,1])

# %%
sns.set_style("whitegrid")
plt.plot([1,2,2,1])

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style({"ytick.left":True,"xtick.top":True})
plt.plot([1,2])

# %%
sns.plotting_context()
# Out:
# {'font.size': 12.0,
#  'axes.labelsize': 12.0,
#  'axes.titlesize': 12.0,
#  'xtick.labelsize': 11.0,
#  'ytick.labelsize': 11.0,
#  'legend.fontsize': 11.0,
#  'axes.linewidth': 1.25,
#  'grid.linewidth': 1.0,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 1.25,
#  'ytick.major.width': 1.25,
#  'xtick.minor.width': 1.0,
#  'ytick.minor.width': 1.0,
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 4.0,
#  'ytick.minor.size': 4.0}

# %%
sns.plotting_context({"xtick.labelsize":20,"ytick.major.size":16})
plt.plot([1,2,2,1])

# %%
sns.set_context("paper")
plt.plot([1,2,2,1])

# %%
sns.set_style("white")
sns.distplot(ccss.s3)
sns.despine()
